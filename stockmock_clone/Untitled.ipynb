# %%
import pandas as pd

# %%
df = pd.read_csv('results2.csv')

# %%
df.drop_duplicates()
# Out:
#            date  ce_entry  pe_entry     ce_sl     pe_sl  ce_exit ce_exit_time  \
# 0      1/6/2016     73.10    119.95   98.6850  161.9325   100.10     10:00:59
# 1      2/6/2016     44.60     74.00   60.2100   99.9000    66.05     10:25:59
# 2      3/6/2016    172.70    177.95  233.1450  240.2325   154.30     15:15:59
# 3      6/6/2016    167.90    179.00  226.6650  241.6500   147.00     15:15:59
# 4      7/6/2016    116.75    195.05  157.6125  263.3175   158.75     12:42:59
# ..          ...       ...       ...       ...       ...      ...          ...
# 699  26/12/2018    165.00    102.50  222.7500  138.3750   230.70     12:17:59
# 700  27/12/2018     93.35     72.70  126.0225   98.1450     0.10     15:15:59
# 701  28/12/2018    205.65    209.00  277.6275  282.1500   175.20     15:15:59
# 704  31/12/2018    193.60    148.15  261.3600  200.0025   176.05     15:15:59
# 705         NaN       NaN       NaN       NaN       NaN      NaN          NaN
#
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (595, 12)

# %%
df.to_csv('removed_duplicates.csv')
